# %%
#pip install 
# !pip install requests beautifulsoup4
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the page
url = "https://www.pro-football-reference.com/teams/phi/2024.htm"

# Send HTTP request to fetch the content of the page
response = requests.get(url)

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the "Team Stats and Rankings" table by its ID
table = soup.find('table', id='team_stats')

# Extract table headers (column names)
headers = [th.text.strip() for th in table.find_all('th')]

# Extract rows (data rows)
rows = []
for row in table.find_all('tr')[1:]:  # Skip the header row
    cells = row.find_all('td')
    if len(cells) == len(headers):  # Ensure the row has the correct number of cells
        row_data = [cell.text.strip() for cell in cells]
        rows.append(row_data)

# Handle cases where some rows might not have the correct number of cells by checking the row length
if rows:
    # Create pandas DataFrame
    df = pd.DataFrame(rows, columns=headers)

    # Display the DataFrame
    print(df)
else:
    print("No valid data rows found.")
# Out:
# No valid data rows found.

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page
url = "https://www.pro-football-reference.com/teams/phi/2024.htm"

# Send HTTP request to fetch the content of the page
response = requests.get(url)

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the "Team Stats and Rankings" table by its ID
table = soup.find('table', id='team_stats')

# Print the raw HTML of the table to inspect its structure
print(table.prettify())  # .prettify() formats the HTML for easier readability
# Out:
# <table class="sortable stats_table" data-cols-to-freeze=",1" id="team_stats">
#  <caption>
#   Team Stats and Rankings Table
#  </caption>
#  <colgroup>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#  </colgroup>
#  <thead>
#   <tr class="over_header">
#    <th>
#    </th>
#    <th>
#    </th>
#    <th>
#    </th>
#    <th aria-label="" class="over_header center" colspan="3" data-stat="header_tot_off_tgl">
#     Tot Yds &amp; TO
#    </th>
#    <th>
#    </th>
#    <th>
#    </th>
#    <th aria-label="" class="over_header center" colspan="7" data-stat="header_pass">
#     Passing
#    </th>
#    <th aria-label="" class="over_header center" colspan="5" data-stat="header_rush">
#     Rushing
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the page
url = "https://www.pro-football-reference.com/teams/phi/2024.htm"

# Send HTTP request to fetch the content of the page
response = requests.get(url)

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the "Team Stats and Rankings" table by its ID
table = soup.find('table', id='team_stats')

# Extract table headers (column names) starting from PF
headers = []
skip_columns = ['Player', 'Tot Yds & TO', 'Passing', 'Rushing', 'Penalties', 'Average Drive']

for th in table.find_all('th'):
    header_text = th.get_text(strip=True)
    # Skip columns such as 'Player' and the first set of statistics
    if header_text not in skip_columns:
        headers.append(header_text)

# Extract rows (data rows)
rows = []
for row in table.find_all('tr')[1:]:  # Skip the header row
    cells = row.find_all('td')
    
    if cells:  # If the row has cells
        # Extract the text and skip the first column ('Player')
        row_data = [cell.get_text(strip=True) for cell in cells[1:]]  # Start from the second column

        # If the row has fewer columns than the headers, fill missing columns with None
        if len(row_data) < len(headers):
            row_data += [None] * (len(headers) - len(row_data))  # Add None to the end to match the header length
        
        rows.append(row_data)

# Create pandas DataFrame using the adjusted headers
df = pd.DataFrame(rows, columns=headers)

# Display the DataFrame
print(df)
# Out:
#                                   PF  Yds   Ply Y/P  ...   TO% Start  Time  \
# 0  6242  1114  5.6  15   9  360  303  448  3194  24  ...  None  None  None
# 1  4732   999  4.7  26  13  293  337  542  2961  22  ...  None  None  None
# 2     8              6  17    6        32    29  12  ...  None  None  None
# 3     1              6   4    1        12     1   6  ...  None  None  None
#
#   Plays   Yds   Pts Team Stats Opp. Stats Lg Rank Offense Lg Rank Defense
# 0  None  None  None       None       None            None            None
# 1  None  None  None       None       None            None            None
# 2  None  None  None       None       None            None            None
# 3  None  None  None       None       None            None            None
#
# [4 rows x 40 columns]

# %%
# Out:
# Empty DataFrame
# Columns: [PF, Yds, Ply, Y/P, TO, FL, 1stD, Cmp, Att, Yds, TD, Int, NY/A, 1stD, Att, Yds, TD, Y/A, 1stD, Pen, Yds, 1stPy, #Dr, Sc%, TO%, Start, Time, Plays, Yds, Pts]
# Index: []
#
# [0 rows x 30 columns]

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page
url = "https://www.pro-football-reference.com/teams/phi/2024.htm"

# Send HTTP request to fetch the content of the page
response = requests.get(url)

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find all tables on the page
tables = soup.find_all('table')

# Print out the number of tables and their structure to locate the "Team Stats and Rankings"
print(f"Found {len(tables)} tables on the page.")

# Let's print the first table's content to see if it's the one we want
first_table = tables[0]
print("First table content:")
print(first_table.prettify()[:1000])  # Print the first 1000 characters of the table for inspection

# Find the table with the specific class or id (you might need to inspect this part depending on the structure)
target_table = None
for table in tables:
    if 'Team Stats and Rankings' in table.get_text():
        target_table = table
        break

if target_table:
    print("Found the 'Team Stats and Rankings' table!")
else:
    print("Couldn't find the 'Team Stats and Rankings' table.")
# Out:
# Found 9 tables on the page.
# First table content:
# <table class="sortable stats_table" data-cols-to-freeze=",1" id="team_stats">
#  <caption>
#   Team Stats and Rankings Table
#  </caption>
#  <colgroup>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#   <col/>
#  </colgroup>
#  <thead>
#   <tr class="over_header">
#    <th>
#    </th>
#    <th>
#    </th>
#    <th>
#    </th>
#    <th aria-label="" class="over_header center" colspan="3" data-stat="header_tot_off_tgl">
#     Tot Yds &amp; TO
#    </th>
#    <th>
#    </th>
#    <th>
#    </th>
#    <th aria-label="" class="over_header center" colspan="7" data-stat="header_pass">
#     Passing
#    </th>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the page
url = "https://www.pro-football-reference.com/teams/phi/2024.htm"

# Send HTTP request to fetch the content of the page
response = requests.get(url)

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find all tables on the page
tables = soup.find_all('table')

# Locate the correct "Team Stats and Rankings" table by inspecting its structure
target_table = None
for table in tables:
    if 'Team Stats and Rankings' in table.get_text():
        target_table = table
        break

# Check if we found the table
if target_table:
    print("Found the 'Team Stats and Rankings' table!")
else:
    print("Couldn't find the 'Team Stats and Rankings' table.")

# Now, let's extract data from the target table

# Extract the headers
headers = [
    'PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp', 'Att', 'Yds', 'TD', 'Int',
    'NY/A', '1stD', 'Att', 'Yds', 'TD', 'Y/A', '1stD', 'Pen', 'Yds', '1stPy', '#Dr',
    'Sc%', 'TO%', 'Start', 'Time', 'Plays', 'Yds', 'Pts'
]

# Extract the first row (excluding the header)
first_row = target_table.find_all('tr')[1]  # Skip the header row
cells = first_row.find_all('td')

# Extract the relevant data for the first row, skipping the 'Player' column (first column)
row_data = [cell.get_text(strip=True) for cell in cells[1:]]  # Skip the first column ('Player')

# Check if the row matches the expected number of columns
print(f"Number of columns in the first row: {len(row_data)}")

# Ensure the row matches the expected number of columns (should match 30 based on headers)
if len(row_data) == len(headers):
    # Create a pandas DataFrame with the first row
    df_first_row = pd.DataFrame([row_data], columns=headers)

    # Display the DataFrame (first row)
    print(df_first_row)
else:
    print("Row does not match expected columns length. Raw data:")
    print(row_data)
# Out:
# Found the 'Team Stats and Rankings' table!
# Number of columns in the first row: 0
# Row does not match expected columns length. Raw data:
# []

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the page
url = "https://www.pro-football-reference.com/teams/phi/2024.htm"

# Send HTTP request to fetch the content of the page
response = requests.get(url)

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find all tables on the page
tables = soup.find_all('table')

# Locate the correct "Team Stats and Rankings" table by inspecting its structure
target_table = None
for table in tables:
    if 'Team Stats and Rankings' in table.get_text():
        target_table = table
        break

# Check if we found the table
if target_table:
    print("Found the 'Team Stats and Rankings' table!")
else:
    print("Couldn't find the 'Team Stats and Rankings' table.")

# Extract the second row of headers (which should contain PF, Yds, Ply, Y/P, etc.)
header_row = target_table.find_all('tr')[1]  # Second row, which contains the actual headers
header_cells = header_row.find_all('th')

# Extract the second set of headers
headers = [header.get_text(strip=True) for header in header_cells]

# Extract the first row of data for the second set of headers
data_row = target_table.find_all('tr')[2]  # The first row of data after the headers
data_cells = data_row.find_all('td')

# Extract data for the first row (ignoring the 'Player' column, which is the first column)
row_data = [cell.get_text(strip=True) for cell in data_cells]

# Ensure the extracted row data matches the header columns
if len(row_data) == len(headers):
    # Create a DataFrame with the second row of headers and its data
    df_first_row = pd.DataFrame([row_data], columns=headers)
    print(df_first_row)
else:
    print("The number of columns in the row does not match the header.")
    print(f"Extracted data: {row_data}")
# Out:
# Found the 'Team Stats and Rankings' table!
# The number of columns in the row does not match the header.
# Extracted data: ['463', '6242', '1114', '5.6', '15', '9', '360', '303', '448', '3194', '24', '6', '6.5', '168', '621', '3048', '29', '4.9', '164', '103', '793', '28', '182', '44.5', '6.6', 'Own 31.7', '3:01', '6.32', '34.2', '2.50']

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the page
url = "https://www.pro-football-reference.com/teams/phi/2024.htm"

# Send HTTP request to fetch the content of the page
response = requests.get(url)

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find all tables on the page
tables = soup.find_all('table')

# Locate the correct "Team Stats and Rankings" table by inspecting its structure
target_table = None
for table in tables:
    if 'Team Stats and Rankings' in table.get_text():
        target_table = table
        break

# Check if we found the table
if target_table:
    print("Found the 'Team Stats and Rankings' table!")
else:
    print("Couldn't find the 'Team Stats and Rankings' table.")

# Extract the second row of headers (which should contain PF, Yds, Ply, Y/P, etc.)
header_row = target_table.find_all('tr')[1]  # Second row, which contains the actual headers
header_cells = header_row.find_all('th')

# Extract the second set of headers
headers = [header.get_text(strip=True) for header in header_cells]

# The headers you provided:
custom_headers = [
    'PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp', 'Att', 'Yds', 'TD', 'Int',
    'NY/A', '1stD', 'Att', 'Yds', 'TD', 'Y/A', '1stD', 'Pen', 'Yds', '1stPy', '#Dr',
    'Sc%', 'TO%', 'Start', 'Time', 'Plays', 'Yds', 'Pts'
]

# Extract the first row of data for the second set of headers
data_row = target_table.find_all('tr')[2]  # The first row of data after the headers
data_cells = data_row.find_all('td')

# Extract data for the first row (ignoring the 'Player' column, which is the first column)
row_data = [cell.get_text(strip=True) for cell in data_cells]

# Ensure the extracted row data matches the custom headers length
if len(row_data) == len(custom_headers):
    # Create a DataFrame with the custom headers and its data
    df_first_row = pd.DataFrame([row_data], columns=custom_headers)
    print(df_first_row)
else:
    print("The number of columns in the row does not match the custom headers.")
    print(f"Extracted data: {row_data}")
# Out:
# Found the 'Team Stats and Rankings' table!
#     PF   Yds   Ply  Y/P  TO FL 1stD  Cmp  Att   Yds  ...  Yds 1stPy  #Dr  \
# 0  463  6242  1114  5.6  15  9  360  303  448  3194  ...  793    28  182
#
#     Sc%  TO%     Start  Time Plays   Yds   Pts
# 0  44.5  6.6  Own 31.7  3:01  6.32  34.2  2.50
#
# [1 rows x 30 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the page
url = "https://www.pro-football-reference.com/teams/phi/2024.htm"

# Send HTTP request to fetch the content of the page
response = requests.get(url)

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find all tables on the page
tables = soup.find_all('table')

# Locate the correct "Team Stats and Rankings" table by inspecting its structure
target_table = None
for table in tables:
    if 'Team Stats and Rankings' in table.get_text():
        target_table = table
        break

# Check if we found the table
if target_table:
    print("Found the 'Team Stats and Rankings' table!")
else:
    print("Couldn't find the 'Team Stats and Rankings' table.")

# The headers you provided:
custom_headers = [
    'PF', 'Yds', 'Ply', 'Y/P', 'TO', 'FL', '1stD', 'Cmp', 'Att', 'Yds', 'TD', 'Int',
    'NY/A', '1stD', 'Att', 'Yds', 'TD', 'Y/A', '1stD', 'Pen', 'Yds', '1stPy', '#Dr',
    'Sc%', 'TO%', 'Start', 'Time', 'Plays', 'Yds', 'Pts'
]

# Extract the second data row (which should be the second set of stats)
data_row_2 = target_table.find_all('tr')[3]  # The second row of data after the headers
data_cells_2 = data_row_2.find_all('td')

# Extract data for the second row (ignoring the 'Player' column)
row_data_2 = [cell.get_text(strip=True) for cell in data_cells_2]

# Ensure the extracted row data matches the custom headers length
if len(row_data_2) == len(custom_headers):
    # Create a DataFrame with the custom headers and its data for the second row
    df_second_row = pd.DataFrame([row_data_2], columns=custom_headers)
    print(df_second_row)
else:
    print("The number of columns in the second row does not match the custom headers.")
    print(f"Extracted data for the second row: {row_data_2}")
# Out:
# Found the 'Team Stats and Rankings' table!
#     PF   Yds  Ply  Y/P  TO  FL 1stD  Cmp  Att   Yds  ...  Yds 1stPy  #Dr  \
# 0  303  4732  999  4.7  26  13  293  337  542  2961  ...  694    25  177
#
#     Sc%   TO%     Start  Time Plays   Yds   Pts
# 0  31.6  14.1  Own 30.7  2:39   5.8  26.7  1.65
#
# [1 rows x 30 columns]
